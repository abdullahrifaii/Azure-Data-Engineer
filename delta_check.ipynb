# %%
df = spark.range(1,11)

# %%
df.write.format("delta").mode("overwrite").save("/Volumes/mycatalog/default/myvolume/delta_output")

# %%
js = spark.read.format("json").load("/Volumes/mycatalog/default/myvolume/delta_output/_delta_log/00000000000000000000.json")

# %%
display(js)
