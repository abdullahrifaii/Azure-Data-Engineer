-- %%
select * from dataquality.bronze.purchitem limit 10

-- %%
select * from dataquality.bronze.vendtable limit 10

-- %%
describe history dataquality.bronze.vendtable

-- %%
insert into dataquality.bronze.vendtable values ('1','Vendor1','2022-01-01','2022-01-01','Address1','City1','State1','Country1','ZipCode1','Region1','2022-01-01','2022-01-01','Y','RecordId1','TaxId1','CurrencyCode1')

-- %%
select * from dataquality.bronze.vendtable version as of 0

-- %%
restore table dataquality.bronze.vendtable to version as of 0
