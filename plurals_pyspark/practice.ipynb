# %%
df = spark.table("dataquality.bronze.salesorderline")

# %%
df.printSchema()

# %%
df.rdd.getNumPartitions()

# %%
df.createOrReplaceTempView("sqldf")

# %%
# %sql
describe history dataquality.silver.dimpurchitem

# %%
# %sql
delete from dataquality.silver.dimpurchitem where CategoryID = 500

# %%
# %sql
describe history dataquality.silver.dimpurchitem

# %%
# %sql
restore dataquality.silver.dimpurchitem version as of 1
